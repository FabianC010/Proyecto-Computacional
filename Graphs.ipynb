# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython import display
import calculo_norma as cn
import Diag as dg

#inicializamos figura y plot para animar e asignamos titulos y limites de los ejes
fig = plt.figure()
line, = plt.plot([])
plt.xlabel('Estados')
plt.ylabel('Probabilidad')
plt.xlim(0, dg.psi.size)
plt.ylim(0, 1)
plt.grid(True)

#funcion encargada de conseguir los valores mas nuevos de la animacion
def animate(frame):
    line.set_data(range(dg.psi.size), cn.norma_cuadrada(dg.stateQuant0[frame*skip,:]))
    return line,

skip= 10
anim = FuncAnimation(fig, animate, frames=(dg.times.size//skip), interval=42, blit=True)
video = anim.to_html5_video()
html = display.HTML(anim.to_html5_video())
display.display(html)
plt.close()
# Out:
# Duration: 0.04685235023498535 seconds
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...
